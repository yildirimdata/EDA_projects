# %% [markdown]
# # Exploratory Data Analysis of the Sales data for 12 months of 2019

# %% [markdown]
# TASKS:
#
# - What was the best month for sales? How much was earned that month? Assess the distribution of the sales in terms of months?
#
# - What city sold the most product?
#
# - What time should we display advertisemens to maximize the likelihood of customer’s buying product?
#
# - What products are most often sold together?
#
# - What product sold the most? Why do you think it sold the most?

# %%
# necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import seaborn as sns

import colorama
from colorama import Fore, Style  # makes strings colored
from termcolor import colored
from termcolor import cprint

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# **The csv files are each for a month. I'll merge them in a csv file**

# %%
# first I'll check the columns if they are all the same in all the csv files

csv_list = ["Sales_January_2019.csv", "Sales_February_2019.csv", "Sales_March_2019.csv", "Sales_April_2019.csv", 
            "Sales_May_2019.csv", "Sales_June_2019.csv", "Sales_July_2019.csv", "Sales_August_2019.csv",
           "Sales_September_2019.csv", "Sales_October_2019.csv", "Sales_November_2019.csv", "Sales_December_2019.csv"]

for csv in csv_list:
    print(csv.split('_')[1].upper())
    print("----"*3)
    print(pd.read_csv(csv).columns)    
    print("----"*5)
# Out:
# JANUARY
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# FEBRUARY
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# MARCH
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# APRIL
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# MAY
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# JUNE
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# JULY
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# AUGUST
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# SEPTEMBER
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# OCTOBER
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# NOVEMBER
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------
# DECEMBER
# ------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')
# --------------------

# %%
# Since all the column names are the same, I don't need to rename column names in any of the csv files.
# I can merge them now by using pd.concat

import os

path = "/Users/kadiryildirim/Desktop/DataScience/EDA_sales/SalesAnalysis/Sales_Data"
files = [file for file in os.listdir(path) if not file.startswith(('.', 'Sales_data_analysis'))] # '.' to ignore the hidden files and py notebook

df_original = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(path+"/"+file)
    df_original = pd.concat([df_original, current_data])
    
df_original.to_csv("sales_2019.csv", index=False)

# %%
# I'll create a deep copy to keep my original csv unchanged.

df = df_original.copy()
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# **My user-defined functions to assess the numerical features later**

# %%
def show_nulls(data):
    
    '''
    
    This function plots missing values for each column by observation in the dataset.
    
    ''' 
    plt.figure(figsize=(10, 5))

    sns.displot(data=data.isnull().melt(value_name="missing"),
                y="variable",
                hue="missing",
                multiple="fill",
                height=9.25)

    plt.axvline(0.2, color="r")
    plt.show()

# %% [markdown]
# **Understanding th data and its main features**

# %%
df.shape
# Out:
# (373700, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373700 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          372610 non-null  object
#  1   Product           372610 non-null  object
#  2   Quantity Ordered  372610 non-null  object
#  3   Price Each        372610 non-null  object
#  4   Order Date        372610 non-null  object
#  5   Purchase Address  372610 non-null  object
# dtypes: object(6)
# memory usage: 20.0+ MB

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     372610                372610           372610     372610
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         710                 43806           337104      43806
#
#         Order Date  Purchase Address
# count       372610            372610
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           710               710

# %%
df.size
# Out:
# 2242200

# %%
df.sample(15)
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 41946    192620          Wired Headphones                1      11.99
# 7293     266324    27in 4K Gaming Monitor                1     389.99
# 12687    235055     AA Batteries (4-pack)                1       3.84
# 18714    313542    AAA Batteries (4-pack)                1       2.99
# 17732    193479          Wired Headphones                1      11.99
# 19284    277745    AAA Batteries (4-pack)                1       2.99
# 164388   228195      USB-C Charging Cable                1      11.95
# 27121    178466      USB-C Charging Cable                1      11.95
# 5157     181483  Lightning Charging Cable                1      14.95
# 45349    152265          Wired Headphones                1      11.99
# 15985    209311  Lightning Charging Cable                1      14.95
# 4604     166391          27in FHD Monitor                1     149.99
# 168013   231665  Apple Airpods Headphones                1        150
# 110915   289788    AAA Batteries (4-pack)                1       2.99
# 60565    166801    AAA Batteries (4-pack)                1       2.99
#
#             Order Date                         Purchase Address
# 41946   04/19/19 00:33   179 Chestnut St, Los Angeles, CA 90001
# 7293    10/12/19 13:07  276 Jackson St, New York City, NY 10001
# 12687   07/31/19 02:17     848 Washington St, Atlanta, GA 30301
# 18714   12/26/19 21:45       234 Highland St, Atlanta, GA 30301
# 17732   04/30/19 17:43      105 Elm St, San Francisco, CA 94016
# 19284   10/28/19 10:20      420 9th St, New York City, NY 10001
# 164388  07/03/19 13:50         721 Hickory St, Boston, MA 02215
# 27121   04/13/19 15:08           838 13th St, Seattle, WA 98101
# 5157    04/04/19 12:24             498 4th St, Boston, MA 02215
# 45349   02/03/19 18:28    307 Dogwood St, Los Angeles, CA 90001
# 15985   05/30/19 12:32  505 Jackson St, New York City, NY 10001
# 4604    03/27/19 01:07   419 Center St, San Francisco, CA 94016
# 168013  07/16/19 12:40    255 Jackson St, Los Angeles, CA 90001
# 110915  11/05/19 13:39           658 9th St, Portland, ME 04101
# 60565   03/29/19 14:21             352 2nd St, Austin, TX 73301

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
# pip install skimpy

# %%
# to change the column names
from skimpy import clean_columns

df = clean_columns(df)
# Out:
# 6 column names have been cleaned

# %%
df.head()
# Out:
#   order_id               product quantity_ordered price_each      order_date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          purchase_address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# # CLEANING THE DATA

# %%
#duplicated_values check

df.duplicated().value_counts(dropna=False)
# Out:
# True     188012
# False    185688
# dtype: int64

# %%
df[df.duplicated()].sample(10)
# rows of column names
# Out:
#       order_id                   product quantity_ordered price_each  \
# 61459   167654          27in FHD Monitor                1     149.99
# 3806    213535        LG Washing Machine                1      600.0
# 36116   187056     AA Batteries (4-pack)                1       3.84
# 4138    145154     AA Batteries (4-pack)                2       3.84
# 7671    266689    AAA Batteries (4-pack)                1       2.99
# 153     248300    AAA Batteries (4-pack)                1       2.99
# 3625    251632    AAA Batteries (4-pack)                1       2.99
# 2547    164435  Apple Airpods Headphones                1        150
# 14555   175914          Wired Headphones                1      11.99
# 11151   172662    AAA Batteries (4-pack)                1       2.99
#
#            order_date                        purchase_address
# 61459  03/29/19 15:10          654 5th St, Portland, OR 97035
# 3806   06/16/19 16:59   166 Ridge St, San Francisco, CA 94016
# 36116  04/13/19 12:06         563 Wilson St, Boston, MA 02215
# 4138   01/26/19 19:46  881 Church St, San Francisco, CA 94016
# 7671   10/31/19 09:05   354 Madison St, Los Angeles, CA 90001
# 153    09/01/19 16:57            160 7th St, Boston, MA 02215
# 3625   09/17/19 15:44     36 West St, New York City, NY 10001
# 2547   03/24/19 12:37         112 Adams St, Atlanta, GA 30301
# 14555  03/20/19 14:58        195 Willow St, Atlanta, GA 30301
# 11151  03/25/19 16:57      357 13th St, Los Angeles, CA 90001

# %%
# 1. dropping the NAN rows
df[df.isnull()]
# Out:
#       order_id product quantity_ordered price_each order_date purchase_address
# 0          NaN     NaN              NaN        NaN        NaN              NaN
# 1          NaN     NaN              NaN        NaN        NaN              NaN
# 2          NaN     NaN              NaN        NaN        NaN              NaN
# 3          NaN     NaN              NaN        NaN        NaN              NaN
# 4          NaN     NaN              NaN        NaN        NaN              NaN
# ...        ...     ...              ...        ...        ...              ...
# 13617      NaN     NaN              NaN        NaN        NaN              NaN
# 13618      NaN     NaN              NaN        NaN        NaN              NaN
# 13619      NaN     NaN              NaN        NaN        NaN              NaN
# 13620      NaN     NaN              NaN        NaN        NaN              NaN
# 13621      NaN     NaN              NaN        NaN        NaN              NaN
#
# [373700 rows x 6 columns]

# %%
df.dropna(how='all', inplace=True)

# %%
df = df.rename(columns = {"price_each": "price", "quantity_ordered": "quantity", "order_date": "date", 
                     "purchase_address":"address"})
df.head()
# Out:
#   order_id               product quantity   price            date  \
# 0   295665    Macbook Pro Laptop        1    1700  12/30/19 00:01
# 1   295666    LG Washing Machine        1   600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable        1   11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor        1  149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable        1   11.95  12/18/19 12:38
#
#                                   address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
date_drop = df[df.date=="Order Date"].index
date_drop
# Out:
# Int64Index([  254,   705,  1101,  2875,  3708,  3793,  3812,  4218,  5143,
#              5293,
#             ...
#              6018,  7727,  8251,  8906,  8918, 10443, 10784, 10813, 11047,
#             13304],
#            dtype='int64', length=710)

# %%
df = df.drop(date_drop)

# %%
df[df.date.isnull()]
# Out:
# Empty DataFrame
# Columns: [order_id, product, quantity, price, date, address]
# Index: []

# %%
show_nulls(df);

# %% [markdown]
# # Setting the dtypes of features

# %% [markdown]
# # DATE FEATURE

# %%
df.date.str.isalpha().value_counts()
# Out:
# False    368381
# Name: date, dtype: int64

# %%
df[df.date=="Order Date"]
# Out:
# Empty DataFrame
# Columns: [order_id, product, quantity, price, date, address]
# Index: []

# %%
df.date = pd.to_datetime(df.date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368381 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   order_id  368381 non-null  object
#  1   product   368381 non-null  object
#  2   quantity  368381 non-null  object
#  3   price     368381 non-null  object
#  4   date      368381 non-null  datetime64[ns]
#  5   address   368381 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 19.7+ MB

# %%
df.date.dt.year
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 13617    2019
# 13618    2019
# 13619    2019
# 13620    2019
# 13621    2019
# Name: date, Length: 368381, dtype: int64

# %%
# for ex: let's see the months ordered in terms of order numbers
df.date.dt.month.value_counts()
# Out:
# 12    49360
# 10    40255
# 4     36263
# 11    34855
# 5     32850
# 3     30041
# 7     28325
# 6     26846
# 2     23701
# 8     23680
# 9     22996
# 1     19209
# Name: date, dtype: int64

# %% [markdown]
# # QUANTITY Feature

# %%
df.quantity.value_counts()
# Out:
# 1    333933
# 2     26380
# 3      5783
# 4      1593
# 5       468
# 6       160
# 7        48
# 8        10
# 9         6
# Name: quantity, dtype: int64

# %%
# Since they are all numeric, we can change the dtype of the quantity column to int

df.quantity = df.quantity.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368381 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   order_id  368381 non-null  object
#  1   product   368381 non-null  object
#  2   quantity  368381 non-null  int64
#  3   price     368381 non-null  object
#  4   date      368381 non-null  datetime64[ns]
#  5   address   368381 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 19.7+ MB

# %% [markdown]
# # PRICE Feature

# %%
df.price.value_counts(dropna=False)
# Out:
# 11.95     43383
# 14.95     42934
# 2.99      40901
# 3.84      40752
# 11.99     37402
# 150       30605
# 99.99     26417
# 149.99    14881
# 700       13480
# 389.99    12339
# 379.99    12232
# 600       10879
# 300        9456
# 1700       9314
# 999.99     8172
# 109.99     8127
# 400        4062
# 600.0      2669
# 150.0       198
# 700.0        76
# 1700.0       44
# 300.0        40
# 400.0        18
# Name: price, dtype: int64

# %%
df.price
# Out:
# 0          1700
# 1         600.0
# 2         11.95
# 3        149.99
# 4         11.95
#           ...
# 13617      2.99
# 13618    149.99
# 13619     11.95
# 13620     11.95
# 13621      2.99
# Name: price, Length: 368381, dtype: object

# %%
# We can change its type to numeric
pd.options.display.float_format = '{:.2f}'.format
df.price = df.price.astype(float)
df.price.value_counts(dropna=False)
# Out:
# 11.95      43383
# 14.95      42934
# 2.99       40901
# 3.84       40752
# 11.99      37402
# 150.00     30803
# 99.99      26417
# 149.99     14881
# 700.00     13556
# 600.00     13548
# 389.99     12339
# 379.99     12232
# 300.00      9496
# 1700.00     9358
# 999.99      8172
# 109.99      8127
# 400.00      4080
# Name: price, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368381 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   order_id  368381 non-null  object
#  1   product   368381 non-null  object
#  2   quantity  368381 non-null  int64
#  3   price     368381 non-null  float64
#  4   date      368381 non-null  datetime64[ns]
#  5   address   368381 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 19.7+ MB

# %%
df.isnull().sum()
# Out:
# order_id    0
# product     0
# quantity    0
# price       0
# date        0
# address     0
# dtype: int64

# %%
# I'll check if there are any strange values other than missing values in the object dtype features

print(colored('Descriptive Statistics of Categorical Features:\n', 'blue', attrs=['bold']))

df.describe(include="object").T
# Out:
# Descriptive Statistics of Categorical Features:
#            count  unique                                     top   freq
# order_id  368381  178154                                  160873     10
# product   368381      19                    USB-C Charging Cable  43383
# address   368381  140606  193 Forest St, San Francisco, CA 94016     18

# %%
object_col = df.select_dtypes(include='object').columns
object_col
# Out:
# Index(['order_id', 'product', 'address'], dtype='object')

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# order_id
# ----------------
# 160873    10
# 312462     8
# 289117     8
# 165665     8
# 263918     8
#           ..
# 239673     1
# 239671     1
# 201609     1
# 288921     1
# 260493     1
# Name: order_id, Length: 178154, dtype: int64
# ----------------------------------------
# product
# ----------------
# USB-C Charging Cable          43383
# Lightning Charging Cable      42934
# AAA Batteries (4-pack)        40901
# AA Batteries (4-pack)         40752
# Wired Headphones              37402
# Apple Airpods Headphones      30803
# Bose SoundSport Headphones    26417
# 27in FHD Monitor              14881
# iPhone                        13556
# 27in 4K Gaming Monitor        12339
# 34in Ultrawide Monitor        12232
# Google Phone                  10949
# Flatscreen TV                  9496
# Macbook Pro Laptop             9358
# ThinkPad Laptop                8172
# 20in Monitor                   8127
# Vareebadd Phone                4080
# LG Washing Machine             1313
# LG Dryer                       1286
# Name: product, dtype: int64
# ----------------------------------------
# address
# ----------------
# 193 Forest St, San Francisco, CA 94016    18
# 279 Sunset St, San Francisco, CA 94016    16
# 223 Elm St, Los Angeles, CA 90001         16
# 550 Cherry St, San Francisco, CA 94016    14
# 727 9th St, San Francisco, CA 94016       14
#                                           ..
# 936 7th St, Los Angeles, CA 90001          1
# 611 Pine St, San Francisco, CA 94016       1
# 888 Willow St, New York City, NY 10001     1
# 237 Adams St, Los Angeles, CA 90001        1
# 411 Meadow St, Los Angeles, CA 90001       1
# Name: address, Length: 140606, dtype: int64
# ----------------------------------------

# %% [markdown]
# **So there aren't any strange values in the categorical features. Other features have been already converted to numerical types. Now I'll check the price feature as the main numerical feature to get some initial statistical insights**

# %%
df.describe().T
# Out:
#              count   mean    std  min   25%   50%    75%     max
# quantity 368381.00   1.12   0.44 1.00  1.00  1.00   1.00    9.00
# price    368381.00 184.36 332.71 2.99 11.95 14.95 150.00 1700.00

# %%
print(colored('Descriptive Statistics of the Price Feature:\n', 'blue', attrs=['bold']))

df.price.describe()
# Out:
# Descriptive Statistics of the Price Feature:
# count   368381.00
# mean       184.36
# std        332.71
# min          2.99
# 25%         11.95
# 50%         14.95
# 75%        150.00
# max       1700.00
# Name: price, dtype: float64

# %%
show_distribution(df["price"])
# Out:
# Statistical Calculations :
# --------------------------
# Minimum:   2.99
# Mean:    184.36
# Median:   14.95
# Mode:     11.95
# Maximum:1700.00

# %%
df.head()
# Out:
#   order_id               product  quantity   price                date  \
# 0   295665    Macbook Pro Laptop         1 1700.00 2019-12-30 00:01:00
# 1   295666    LG Washing Machine         1  600.00 2019-12-29 07:03:00
# 2   295667  USB-C Charging Cable         1   11.95 2019-12-12 18:21:00
# 3   295668      27in FHD Monitor         1  149.99 2019-12-22 15:13:00
# 4   295669  USB-C Charging Cable         1   11.95 2019-12-18 12:38:00
#
#                                   address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# # TASK 1: What was the best month for sales? How much was earned that month? Assess the distribution of the sales in terms of months?

# %%
# creating a month feature from the date feature

df["month"] = df.date.dt.month

# %%
df.month.value_counts()
# Out:
# 12    49360
# 10    40255
# 4     36263
# 11    34855
# 5     32850
# 3     30041
# 7     28325
# 6     26846
# 2     23701
# 8     23680
# 9     22996
# 1     19209
# Name: month, dtype: int64

# %%
df.head(1)
# Out:
#   order_id             product  quantity   price                date  \
# 0   295665  Macbook Pro Laptop         1 1700.00 2019-12-30 00:01:00
#
#                                   address  month
# 0  136 Church St, New York City, NY 10001     12

# %%
# checking the values of quantity feature
df.quantity.value_counts()
# Out:
# 1    333933
# 2     26380
# 3      5783
# 4      1593
# 5       468
# 6       160
# 7        48
# 8        10
# 9         6
# Name: quantity, dtype: int64

# %%
df[df.quantity>6]
# the price is not for the entire order, it's for each single product. 
# Thus I'll create a sales feature
# Out:
#      order_id                 product  quantity  price                date  \
# 672    296304  AAA Batteries (4-pack)         7   2.99 2019-12-23 18:27:00
# 4258   299713   AA Batteries (4-pack)         7   3.84 2019-12-17 20:56:00
# 9471   304696  AAA Batteries (4-pack)         7   2.99 2019-12-02 21:21:00
# 628    177160  AAA Batteries (4-pack)         7   2.99 2019-04-26 11:37:00
# 672    296304  AAA Batteries (4-pack)         7   2.99 2019-12-23 18:27:00
# ...       ...                     ...       ...    ...                 ...
# 2363   225181   AA Batteries (4-pack)         7   3.84 2019-07-05 13:50:00
# 3740   226483  AAA Batteries (4-pack)         9   2.99 2019-07-20 23:28:00
# 4376   227096  AAA Batteries (4-pack)         9   2.99 2019-07-29 09:50:00
# 5725   228384  AAA Batteries (4-pack)         7   2.99 2019-07-06 17:34:00
# 1236   211097  AAA Batteries (4-pack)         9   2.99 2019-06-23 08:29:00
#
#                                        address  month
# 672   567 Highland St, San Francisco, CA 94016     12
# 4258          160 Hickory St, Dallas, TX 75001     12
# 9471            393 West St, Atlanta, GA 30301     12
# 628               689 7th St, Dallas, TX 75001      4
# 672   567 Highland St, San Francisco, CA 94016     12
# ...                                        ...    ...
# 2363           349 Walnut St, Dallas, TX 75001      7
# 3740    867 Sunset St, San Francisco, CA 94016      7
# 4376       60 10th St, San Francisco, CA 94016      7
# 5725          78 Highland St, Austin, TX 73301      7
# 1236     338 Hickory St, Los Angeles, CA 90001      6
#
# [64 rows x 7 columns]

# %%
df["sales"] = df.price * df.quantity

# %%
df.head()
# Out:
#   order_id               product  quantity   price                date  \
# 0   295665    Macbook Pro Laptop         1 1700.00 2019-12-30 00:01:00
# 1   295666    LG Washing Machine         1  600.00 2019-12-29 07:03:00
# 2   295667  USB-C Charging Cable         1   11.95 2019-12-12 18:21:00
# 3   295668      27in FHD Monitor         1  149.99 2019-12-22 15:13:00
# 4   295669  USB-C Charging Cable         1   11.95 2019-12-18 12:38:00
#
#                                   address  month   sales
# 0  136 Church St, New York City, NY 10001     12 1700.00
# 1     562 2nd St, New York City, NY 10001     12  600.00
# 2    277 Main St, New York City, NY 10001     12   11.95
# 3     410 6th St, San Francisco, CA 94016     12  149.99
# 4           43 Hill St, Atlanta, GA 30301     12   11.95

# %%
# grouping the months by sales

total_sales = df.groupby("month")[["sales"]].sum().sort_values("sales", ascending=False)
total_sales
# Out:
#            sales
# month
# 12    9115810.84
# 10    7415981.04
# 4     6727046.66
# 11    6349388.29
# 5     6254487.79
# 3     5563069.78
# 7     5235220.67
# 6     5102267.25
# 8     4436166.19
# 2     4360149.90
# 9     4147921.39
# 1     3608768.02

# %%
# average sales for each month
monthly_sales = df.groupby("month")[["sales"]].mean()
monthly_sales
# Out:
#        sales
# month
# 1     187.87
# 2     183.96
# 3     185.18
# 4     185.51
# 5     190.40
# 6     190.06
# 7     184.83
# 8     187.34
# 9     180.38
# 10    184.23
# 11    182.17
# 12    184.68

# %%
monthly_sales.reset_index(inplace=True)

# %%
total_sales.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax = sns.barplot(x = total_sales.month, y = total_sales.sales)

plt.title("Total sales increases significantly in December", fontdict = {"fontsize":15, "color": "red"})

ax.bar_label(ax.containers[0], labels = [f'{x}' for x in total_sales.sales], size = 9);

# %% [markdown]
# **Result 1:**
#
# December is the best month in terms of total sales. Total amount of sales for this month is $4,557,905.42.
#
# The sales decrease in summer months and also sharply decreases in January. This is highly likely due to the increase during the christmas and noel period.

# %% [markdown]
# # TASK 2: What city sold the most product?

# %%
# to answer this question we have to use some feature engineering on the address column and create a city feature

df.sample(20)
# Out:
#        order_id                     product  quantity  price  \
# 7936     184135      AAA Batteries (4-pack)         2   2.99
# 11101    172613                Google Phone         1 600.00
# 2680     153058            Wired Headphones         1  11.99
# 57437    163819        USB-C Charging Cable         1  11.95
# 28589    179885  Bose SoundSport Headphones         1  99.99
# 10431    232889            Wired Headphones         1  11.99
# 8225     244541            27in FHD Monitor         1 149.99
# 3582     197496            27in FHD Monitor         1 149.99
# 185250   221389       AA Batteries (4-pack)         1   3.84
# 15068    190927        USB-C Charging Cable         1  11.95
# 61893    168073    Lightning Charging Cable         1  14.95
# 8589     218110      AAA Batteries (4-pack)         1   2.99
# 147988   248939            27in FHD Monitor         1 149.99
# 55206    161691    Lightning Charging Cable         1  14.95
# 7186     255035      AAA Batteries (4-pack)         1   2.99
# 785      223664    Lightning Charging Cable         1  14.95
# 1356     151798      AAA Batteries (4-pack)         1   2.99
# 18729    313557            Wired Headphones         1  11.99
# 17027    311939      AAA Batteries (4-pack)         3   2.99
# 9470     185599            Wired Headphones         1  11.99
#
#                       date                                   address  month  \
# 7936   2019-04-06 15:48:00          206 Hickory St, Boston, MA 02215      4
# 11101  2019-03-29 12:52:00        246 Highland St, Atlanta, GA 30301      3
# 2680   2019-02-17 22:00:00              719 Elm St, Dallas, TX 75001      2
# 57437  2019-03-07 12:26:00        395 13th St, Los Angeles, CA 90001      3
# 28589  2019-04-26 17:53:00      369 13th St, New York City, NY 10001      4
# 10431  2019-07-08 11:08:00        948 10th St, Los Angeles, CA 90001      7
# 8225   2019-08-18 12:20:00      688 10th St, New York City, NY 10001      8
# 3582   2019-05-15 20:46:00  305 Washington St, Los Angeles, CA 90001      5
# 185250 2019-06-03 21:19:00       935 River St, Los Angeles, CA 90001      6
# 15068  2019-04-10 22:19:00    438 Meadow St, New York City, NY 10001      4
# 61893  2019-03-19 10:47:00    294 Spruce St, San Francisco, CA 94016      3
# 8589   2019-06-20 23:20:00           526 Forest St, Dallas, TX 75001      6
# 147988 2019-09-08 00:29:00        319 Lake St, Los Angeles, CA 90001      9
# 55206  2019-02-12 21:46:00     120 Maple St, New York City, NY 10001      2
# 7186   2019-09-30 14:32:00       584 2nd St, New York City, NY 10001      9
# 785    2019-07-29 20:26:00            817 North St, Boston, MA 02215      7
# 1356   2019-02-16 13:14:00         797 4th St, Los Angeles, CA 90001      2
# 18729  2019-12-22 10:44:00     949 Adams St, San Francisco, CA 94016     12
# 17027  2019-12-21 11:19:00          467 Walnut St, Seattle, WA 98101     12
# 9470   2019-04-15 20:14:00            532 1st St, Portland, OR 97035      4
#
#         sales
# 7936     5.98
# 11101  600.00
# 2680    11.99
# 57437   11.95
# 28589   99.99
# 10431   11.99
# 8225   149.99
# 3582   149.99
# 185250   3.84
# 15068   11.95
# 61893   14.95
# 8589     2.99
# 147988 149.99
# 55206   14.95
# 7186     2.99
# 785     14.95
# 1356     2.99
# 18729   11.99
# 17027    8.97
# 9470    11.99

# %%
df.address.str.split(",", expand=True).iloc[:,1].value_counts()
# Out:
#  San Francisco    88607
#  Los Angeles      58660
#  New York City    49296
#  Boston           39478
#  Atlanta          29474
#  Dallas           29367
#  Seattle          29194
#  Portland         24707
#  Austin           19598
# Name: 1, dtype: int64

# %%
df["city"] = df.address.str.split(",", expand=True).iloc[:,1]

# %%
df.head()
# Out:
#   order_id               product  quantity   price                date  \
# 0   295665    Macbook Pro Laptop         1 1700.00 2019-12-30 00:01:00
# 1   295666    LG Washing Machine         1  600.00 2019-12-29 07:03:00
# 2   295667  USB-C Charging Cable         1   11.95 2019-12-12 18:21:00
# 3   295668      27in FHD Monitor         1  149.99 2019-12-22 15:13:00
# 4   295669  USB-C Charging Cable         1   11.95 2019-12-18 12:38:00
#
#                                   address  month   sales            city
# 0  136 Church St, New York City, NY 10001     12 1700.00   New York City
# 1     562 2nd St, New York City, NY 10001     12  600.00   New York City
# 2    277 Main St, New York City, NY 10001     12   11.95   New York City
# 3     410 6th St, San Francisco, CA 94016     12  149.99   San Francisco
# 4           43 Hill St, Atlanta, GA 30301     12   11.95         Atlanta

# %%
city_sales = df.groupby("city")[["sales"]].sum().sort_values("sales", ascending=False)

# %%
city_sales
# Out:
#                      sales
# city
#  San Francisco 16374798.56
#  Los Angeles   10799380.02
#  New York City  9236110.82
#  Boston         7260812.95
#  Atlanta        5532057.02
#  Dallas         5481665.89
#  Seattle        5435069.32
#  Portland       4593318.04
#  Austin         3603065.20

# %%
city_sales.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax = sns.barplot(x = city_sales.city, y = city_sales.sales)

plt.title("Most sales are in San Fransisco", fontdict = {"fontsize":15, "color": "red"})

ax.bar_label(ax.containers[0], labels = [f'{x}' for x in city_sales.sales], size = 9);

# %%
df.head()
# Out:
#   order_id               product  quantity   price                date  \
# 0   295665    Macbook Pro Laptop         1 1700.00 2019-12-30 00:01:00
# 1   295666    LG Washing Machine         1  600.00 2019-12-29 07:03:00
# 2   295667  USB-C Charging Cable         1   11.95 2019-12-12 18:21:00
# 3   295668      27in FHD Monitor         1  149.99 2019-12-22 15:13:00
# 4   295669  USB-C Charging Cable         1   11.95 2019-12-18 12:38:00
#
#                                   address  month   sales            city
# 0  136 Church St, New York City, NY 10001     12 1700.00   New York City
# 1     562 2nd St, New York City, NY 10001     12  600.00   New York City
# 2    277 Main St, New York City, NY 10001     12   11.95   New York City
# 3     410 6th St, San Francisco, CA 94016     12  149.99   San Francisco
# 4           43 Hill St, Atlanta, GA 30301     12   11.95         Atlanta

# %% [markdown]
# **Result 2:**
#
# San Franscisco is the city with the most sales.

# %% [markdown]
# # TASK 3: What time should we display advertisemens to maximize the likelihood of customer’s buying product?

# %%
# I'll create a feature for the daily hours from the date feature
df["hour"] = df.date.dt.hour

# %%
df.head()
# Out:
#   order_id               product  quantity   price                date  \
# 0   295665    Macbook Pro Laptop         1 1700.00 2019-12-30 00:01:00
# 1   295666    LG Washing Machine         1  600.00 2019-12-29 07:03:00
# 2   295667  USB-C Charging Cable         1   11.95 2019-12-12 18:21:00
# 3   295668      27in FHD Monitor         1  149.99 2019-12-22 15:13:00
# 4   295669  USB-C Charging Cable         1   11.95 2019-12-18 12:38:00
#
#                                   address  month   sales            city  hour
# 0  136 Church St, New York City, NY 10001     12 1700.00   New York City     0
# 1     562 2nd St, New York City, NY 10001     12  600.00   New York City     7
# 2    277 Main St, New York City, NY 10001     12   11.95   New York City    18
# 3     410 6th St, San Francisco, CA 94016     12  149.99   San Francisco    15
# 4           43 Hill St, Atlanta, GA 30301     12   11.95         Atlanta    12

# %%
hourly_transactions =  df.hour.value_counts()

# %%
hourly_transactions = df.hour.value_counts().reset_index().sort_values("index")

# %%
hourly_transactions = hourly_transactions.reset_index()

# %%
hourly_transactions.drop("level_0", axis=1,inplace=True)

# %%
hourly_transactions.rename(columns={"month" : "hour", "hour":"transaction_numbers"}, inplace=True)

# %%
hourly_transactions
# Out:
#     index  transaction_numbers
# 0       0                 7747
# 1       1                 4659
# 2       2                 2469
# 3       3                 1646
# 4       4                 1696
# 5       5                 2611
# 6       6                 4923
# 7       7                 7950
# 8       8                12438
# 9       9                17315
# 10     10                21649
# 11     11                24596
# 12     12                24926
# 13     13                24021
# 14     14                21774
# 15     15                20132
# 16     16                20539
# 17     17                21587
# 18     18                24335
# 19     19                25570
# 20     20                24249
# 21     21                21641
# 22     22                17472
# 23     23                12436

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax = sns.barplot(x = hourly_transactions.index, y = hourly_transactions.transaction_numbers)

plt.title("Hourly distributions of the transactions", fontdict = {"fontsize":15, "color": "red"})

ax.bar_label(ax.containers[0], size = 9);

# %%
hourly_sales = df.groupby("hour")[["sales"]].sum().reset_index()
hourly_sales
# Out:
#     hour      sales
# 0      0 1411928.48
# 1      1  908378.88
# 2      2  469030.57
# 3      3  288730.59
# 4      4  324007.74
# 5      5  453969.57
# 6      6  888897.30
# 7      7 1477325.11
# 8      8 2373097.78
# 9      9 3249238.01
# 10    10 3848181.12
# 11    11 4564663.20
# 12    12 4584224.36
# 13    13 4270129.99
# 14    14 4124891.21
# 15    15 3835625.56
# 16    16 3764426.72
# 17    17 4211640.05
# 18    18 4390717.79
# 19    19 4779514.58
# 20    20 4521765.27
# 21    21 4053938.53
# 22    22 3184156.68
# 23    23 2337798.73

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax = sns.barplot(x = hourly_sales.hour, y = hourly_sales.sales)

plt.title("Hourly distributions of total sales", fontdict = {"fontsize":15, "color": "red"})

ax.bar_label(ax.containers[0], fmt='%.0d', size = 6);

# %% [markdown]
# **Assessment**
#
# As it can be seen from the graph, the number of transactions decreases at night and increases afterwith 10 am. In this regard, the transaction number increases significantly in the period from 11.00 to 13.00 and from 18.00 to 20.00. Hourly distribution of total sales also show this pattern. So it's better to make advertisements just before these periods and during these periods.

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax = sns.swarmplot(x = hourly_sales.hour, y = hourly_sales.sales)

plt.title("Total sales make peaks in the hours from 11.00 to 13.00 and 18.00 to 20.00",
          fontdict = {"fontsize":15, "color": "red"});

# %% [markdown]
# # What products are most often sold together?

# %%
df.drop_duplicates(keep="first", inplace=True)

# %%
df["product"].value_counts()
# Out:
# USB-C Charging Cable          21816
# Lightning Charging Cable      21578
# AAA Batteries (4-pack)        20579
# AA Batteries (4-pack)         20519
# Wired Headphones              18817
# Apple Airpods Headphones      15506
# Bose SoundSport Headphones    13281
# 27in FHD Monitor               7486
# iPhone                         6829
# 27in 4K Gaming Monitor         6212
# 34in Ultrawide Monitor         6167
# Google Phone                   5513
# Flatscreen TV                  4785
# Macbook Pro Laptop             4714
# ThinkPad Laptop                4118
# 20in Monitor                   4092
# Vareebadd Phone                2060
# LG Washing Machine              664
# LG Dryer                        646
# Name: product, dtype: int64

# %%
df.loc[df.order_id.value_counts(ascending = False)].head(20)
# Out:
#   order_id                product  quantity  price                date  \
# 5   295670  AA Batteries (4-pack)         1   3.84 2019-12-31 22:58:00
# 5   176561       Wired Headphones         1  11.99 2019-04-30 09:27:00
# 4   295669   USB-C Charging Cable         1  11.95 2019-12-18 12:38:00
# 4   176560       Wired Headphones         1  11.99 2019-04-12 14:38:00
# 4   295669   USB-C Charging Cable         1  11.95 2019-12-18 12:38:00
# 4   176560       Wired Headphones         1  11.99 2019-04-12 14:38:00
# 4   295669   USB-C Charging Cable         1  11.95 2019-12-18 12:38:00
# 4   176560       Wired Headphones         1  11.99 2019-04-12 14:38:00
# 4   295669   USB-C Charging Cable         1  11.95 2019-12-18 12:38:00
# 4   176560       Wired Headphones         1  11.99 2019-04-12 14:38:00
# 4   295669   USB-C Charging Cable         1  11.95 2019-12-18 12:38:00
# 4   176560       Wired Headphones         1  11.99 2019-04-12 14:38:00
# 4   295669   USB-C Charging Cable         1  11.95 2019-12-18 12:38:00
# 4   176560       Wired Headphones         1  11.99 2019-04-12 14:38:00
# 4   295669   USB-C Charging Cable         1  11.95 2019-12-18 12:38:00
# 4   176560       Wired Headphones         1  11.99 2019-04-12 14:38:00
# 4   295669   USB-C Charging Cable         1  11.95 2019-12-18 12:38:00
# 4   176560       Wired Headphones         1  11.99 2019-04-12 14:38:00
# 4   295669   USB-C Charging Cable         1  11.95 2019-12-18 12:38:00
# 4   176560       Wired Headphones         1  11.99 2019-04-12 14:38:00
#
#                                      address  month  sales            city  \
# 5  200 Jefferson St, New York City, NY 10001     12   3.84   New York City
# 5          333 8th St, Los Angeles, CA 90001      4  11.99     Los Angeles
# 4              43 Hill St, Atlanta, GA 30301     12  11.95         Atlanta
# 4       669 Spruce St, Los Angeles, CA 90001      4  11.99     Los Angeles
# 4              43 Hill St, Atlanta, GA 30301     12  11.95         Atlanta
# 4       669 Spruce St, Los Angeles, CA 90001      4  11.99     Los Angeles
# 4              43 Hill St, Atlanta, GA 30301     12  11.95         Atlanta
# 4       669 Spruce St, Los Angeles, CA 90001      4  11.99     Los Angeles
# 4              43 Hill St, Atlanta, GA 30301     12  11.95         Atlanta
# 4       669 Spruce St, Los Angeles, CA 90001      4  11.99     Los Angeles
# 4              43 Hill St, Atlanta, GA 30301     12  11.95         Atlanta
# 4       669 Spruce St, Los Angeles, CA 90001      4  11.99     Los Angeles
# 4              43 Hill St, Atlanta, GA 30301     12  11.95         Atlanta
# 4       669 Spruce St, Los Angeles, CA 90001      4  11.99     Los Angeles
# 4              43 Hill St, Atlanta, GA 30301     12  11.95         Atlanta
# 4       669 Spruce St, Los Angeles, CA 90001      4  11.99     Los Angeles
# 4              43 Hill St, Atlanta, GA 30301     12  11.95         Atlanta
# 4       669 Spruce St, Los Angeles, CA 90001      4  11.99     Los Angeles
# 4              43 Hill St, Atlanta, GA 30301     12  11.95         Atlanta
# 4       669 Spruce St, Los Angeles, CA 90001      4  11.99     Los Angeles
#
#    hour
# 5    22
# 5     9
# 4    12
# 4    14
# 4    12
# 4    14
# 4    12
# 4    14
# 4    12
# 4    14
# 4    12
# 4    14
# 4    12
# 4    14
# 4    12
# 4    14
# 4    12
# 4    14
# 4    12
# 4    14

# %%
df.duplicated().value_counts()
# Out:
# False    185382
# dtype: int64

# %%
from itertools import combinations
from collections import Counter

most_sold = Counter([
    t for _, d in df.groupby('order_id').product
    for t in combinations(d, 2)
]).most_common(10)

most_sold
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1000),
#  (('Google Phone', 'USB-C Charging Cable'), 983),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 412),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 360),
#  (('iPhone', 'Apple Airpods Headphones'), 357),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 159),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %%
most_sold_product = []
for i in most_sold:
    most_sold_product.append(i[0])

print(most_sold_product)
# Out:
# [('iPhone', 'Lightning Charging Cable'), ('Google Phone', 'USB-C Charging Cable'), ('iPhone', 'Wired Headphones'), ('Google Phone', 'Wired Headphones'), ('Vareebadd Phone', 'USB-C Charging Cable'), ('iPhone', 'Apple Airpods Headphones'), ('Google Phone', 'Bose SoundSport Headphones'), ('USB-C Charging Cable', 'Wired Headphones'), ('Vareebadd Phone', 'Wired Headphones'), ('Lightning Charging Cable', 'Wired Headphones')]

# %%
most_sold_quantity = []
for i in most_sold:
    most_sold_quantity.append(i[1])

print(most_sold_quantity)
# Out:
# [1000, 983, 447, 412, 360, 357, 220, 159, 143, 92]

# %%
most_sold_df = pd.DataFrame(most_sold, columns = ["product_pairs", "number_of_sales"])

# %%
most_sold_df
# Out:
#                                   product_pairs  number_of_sales
# 0            (iPhone, Lightning Charging Cable)             1000
# 1          (Google Phone, USB-C Charging Cable)              983
# 2                    (iPhone, Wired Headphones)              447
# 3              (Google Phone, Wired Headphones)              412
# 4       (Vareebadd Phone, USB-C Charging Cable)              360
# 5            (iPhone, Apple Airpods Headphones)              357
# 6    (Google Phone, Bose SoundSport Headphones)              220
# 7      (USB-C Charging Cable, Wired Headphones)              159
# 8           (Vareebadd Phone, Wired Headphones)              143
# 9  (Lightning Charging Cable, Wired Headphones)               92

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax = sns.barplot(x = most_sold_df.product_pairs, y = most_sold_df.number_of_sales)

plt.title("The first ten products which often sold together", fontdict = {"fontsize":15, "color": "red"})
plt.xticks(rotation="vertical")

ax.bar_label(ax.containers[0], fmt='%.0d', size = 10);

# %%
most_sold_df["percentage"] = most_sold_df.number_of_sales.apply(lambda x: 100 * x /most_sold_df.number_of_sales.sum())

# %%
most_sold_df
# Out:
#                                   product_pairs  number_of_sales  percentage
# 0            (iPhone, Lightning Charging Cable)             1000       23.96
# 1          (Google Phone, USB-C Charging Cable)              983       23.56
# 2                    (iPhone, Wired Headphones)              447       10.71
# 3              (Google Phone, Wired Headphones)              412        9.87
# 4       (Vareebadd Phone, USB-C Charging Cable)              360        8.63
# 5            (iPhone, Apple Airpods Headphones)              357        8.55
# 6    (Google Phone, Bose SoundSport Headphones)              220        5.27
# 7      (USB-C Charging Cable, Wired Headphones)              159        3.81
# 8           (Vareebadd Phone, Wired Headphones)              143        3.43
# 9  (Lightning Charging Cable, Wired Headphones)               92        2.20

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax = sns.barplot(x = most_sold_df.product_pairs, y = most_sold_df.percentage)

plt.title("The percentage of first ten products which often sold together", fontdict = {"fontsize":15, "color": "red"})
plt.xticks(rotation="vertical")

ax.bar_label(ax.containers[0], fmt='%.0d%%', size = 10);

# %%
fig, ax = plt.subplots(figsize=(12, 9))

ax.pie(x=most_sold_df.percentage, 
       labels=most_sold_df.product_pairs, 
       autopct='%.0f%%',
       colors=['lightskyblue', 'gold'],
       textprops={'fontsize': 12},
       shadow=True
       )
plt.title("Distribution offirst ten products which often sold together", fontdict = {'fontsize': 14, "color" : "red"})
plt.show()

# %% [markdown]
# **Result**
#
# Google phone-USB-C  and iPhone-Lightning charging cable product pairs are the most sold product pairs. These both correspond almost to the half of the total orders.

# %% [markdown]
# # TASK 5
#
# What product sold the most? Why do you think it sold the most?

# %%
df["product"].value_counts(ascending=False).head(5)
# Out:
# USB-C Charging Cable        21816
# Lightning Charging Cable    21578
# AAA Batteries (4-pack)      20579
# AA Batteries (4-pack)       20519
# Wired Headphones            18817
# Name: product, dtype: int64

# %%
most_product = pd.DataFrame(df.groupby("product")[["price"]].value_counts())

# %%
most_product.reset_index(inplace=True)

# %%
most_product.rename(columns = {0:"number_of_sales"}, inplace=True)

# %%
most_product["percentage"] = most_product.number_of_sales.apply(lambda x: 100 * x /most_product.number_of_sales.sum())

# %%
most_product.sort_values("percentage", ascending= False, ignore_index=True, inplace=True)

# %%
most_product = most_product.iloc[0:5]

# %%
most_product
# Out:
#                     product  price  number_of_sales  percentage
# 0      USB-C Charging Cable  11.95            21816       11.77
# 1  Lightning Charging Cable  14.95            21578       11.64
# 2    AAA Batteries (4-pack)   2.99            20579       11.10
# 3     AA Batteries (4-pack)   3.84            20519       11.07
# 4          Wired Headphones  11.99            18817       10.15

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax = sns.barplot(x = most_product["product"], y = most_product.number_of_sales)

plt.title("5 most sold products", fontdict = {"fontsize":15, "color": "red"})
plt.xticks(rotation=45)

ax.bar_label(ax.containers[0], fmt='%.0d', size = 10);

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax = sns.barplot(x = most_product["product"], y = most_product.percentage)

plt.title("Percentage of 5 most sold products", fontdict = {"fontsize":15, "color": "red"})
plt.xticks(rotation=45)

ax.bar_label(ax.containers[0], fmt='%.0d%%', size = 10);

# %%
fig, ax = plt.subplots(figsize=(12, 9))

ax.pie(x=most_product["percentage"], 
       labels=most_product["product"], 
       autopct='%.0f%%',
       colors=['lightskyblue', 'gold'],
       textprops={'fontsize': 12},
       shadow=True
       )
plt.title("Distribution of most sold products", fontdict = {'fontsize': 14, "color" : "red"})
plt.show()

# %% [markdown]
# **Result**
#
# Most sold products are complementary products such as charging cables, batteries or headphones which can be used almost withh all electronic devices. Whoever buys an electronic device, they also buy these complementary products.

# %%
df.head()
# Out:
#   order_id               product  quantity   price                date  \
# 0   295665    Macbook Pro Laptop         1 1700.00 2019-12-30 00:01:00
# 1   295666    LG Washing Machine         1  600.00 2019-12-29 07:03:00
# 2   295667  USB-C Charging Cable         1   11.95 2019-12-12 18:21:00
# 3   295668      27in FHD Monitor         1  149.99 2019-12-22 15:13:00
# 4   295669  USB-C Charging Cable         1   11.95 2019-12-18 12:38:00
#
#                                   address  month   sales            city  hour
# 0  136 Church St, New York City, NY 10001     12 1700.00   New York City     0
# 1     562 2nd St, New York City, NY 10001     12  600.00   New York City     7
# 2    277 Main St, New York City, NY 10001     12   11.95   New York City    18
# 3     410 6th St, San Francisco, CA 94016     12  149.99   San Francisco    15
# 4           43 Hill St, Atlanta, GA 30301     12   11.95         Atlanta    12
